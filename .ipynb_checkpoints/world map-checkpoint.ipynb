# %%
import pandas as pd
import geopandas as gpd

# %%
csv_file = "output/confirmed_cases_sum.csv"
data = pd.read_csv(csv_file)
data.head()
# Out:
#    ID Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0   0    Afghanistan  33.0000  65.0000        0        0        0        0
# 1   1        Albania  41.1533  20.1683        0        0        0        0
# 2   2        Algeria  28.0339   1.6596        0        0        0        0
# 3   3        Andorra  42.5063   1.5218        0        0        0        0
# 4   4         Angola -11.2027  17.8739        0        0        0        0
#
#    1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  4/17/20  \
# 0        0        0  ...      665      714      784      840      906
# 1        0        0  ...      467      475      494      518      539
# 2        0        0  ...     1983     2070     2160     2268     2418
# 3        0        0  ...      646      659      673      673      696
# 4        0        0  ...       19       19       19       19       19
#
#    4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# ...

# %%
data = data.drop(columns=["ID", "Lat", "Long"])

# %%
data.transpose = data.T

# %%
map_file = "World_Map.shp"
world = gpd.read_file(map_file)

# %%
world.plot
# Out:
# <bound method GeoDataFrame.plot of                                      NAME  \
# 0                     Antigua and Barbuda
# 1                                 Algeria
# 2                              Azerbaijan
# 3                                 Albania
# 4                                 Armenia
# ..                                    ...
# 240                      Saint Barthelemy
# 241                              Guernsey
# 242                                Jersey
# 243  South Georgia South Sandwich Islands
# 244                                Taiwan
#
#                                               geometry
# 0    MULTIPOLYGON (((-61.68667 17.02444, -61.73806 ...
# 1    POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 2    MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...
# 3    POLYGON ((19.43621 41.02107, 19.45055 41.06000...
# 4    MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...
# ..                                                 ...
# ...

# %%
data = data.set_index('Country/Region')
data.head(5)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/13/20  4/14/20  4/15/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...      665      714      784
# Albania               0        0        0  ...      467      475      494
# Algeria               0        0        0  ...     1983     2070     2160
# Andorra               0        0        0  ...      646      659      673
# ...
