# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
cases_file = "sources/time_series_covid19_confirmed_global.csv"
confirmed_cases_df = pd.read_csv(cases_file)
confirmed_cases_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...      665      714      784      840
# 1        0        0        0  ...      467      475      494      518
# 2        0        0        0  ...     1983     2070     2160     2268
# 3        0        0        0  ...      646      659      673      673
# 4        0        0        0  ...       19       19       19       19
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0      906      933      996     1026     1092     1176
# 1      539      548      562      584      609      634
# 2     2418     2534     2629     2718     2811     2910
# 3      696      704      713      717      717      723
# 4       19       24       24       24       24       25
#
# [5 rows x 96 columns]

# %%
deaths_file = "sources/time_series_covid19_deaths_global.csv"
deaths_df = pd.read_csv(deaths_file)
deaths_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...       21       23       25       30
# 1        0        0        0  ...       23       24       25       26
# 2        0        0        0  ...      313      326      336      348
# 3        0        0        0  ...       29       31       33       33
# 4        0        0        0  ...        2        2        2        2
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0       30       30       33       36       36       40
# 1       26       26       26       26       26       27
# 2      364      367      375      384      392      402
# 3       35       35       36       37       37       37
# 4        2        2        2        2        2        2
#
# [5 rows x 96 columns]

# %%
recovered_file = "sources/time_series_covid19_recovered_global.csv"
recovered_cases_df = pd.read_csv(recovered_file)
recovered_cases_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0        0        0        0  ...       32       40       43       54
# 1        0        0        0  ...      232      248      251      277
# 2        0        0        0  ...      601      691      708      783
# 3        0        0        0  ...      128      128      169      169
# 4        0        0        0  ...        4        5        5        5
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0       99      112      131      135      150      166
# 1      283      302      314      327      345      356
# 2      846      894     1047     1099     1152     1204
# 3      191      205      235      248      282      309
# 4        5        6        6        6        6        6
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Transform DataFrame

# %%
#List column header to check if there are different entries in each file
confirmed_col = confirmed_cases_df.columns
deaths_col= deaths_df.columns
recovered_col = recovered_cases_df.columns

difference_test1 = confirmed_col.difference(deaths_col)
difference_test1
# Out:
# Index([], dtype='object')

# %%
difference_test2= deaths_col.difference(recovered_col)
difference_test2
# Out:
# Index([], dtype='object')

# %%
set(confirmed_cases_df.columns).intersection(set(deaths_df .columns))
# Out:
# {'1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/2/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '3/1/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/2/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
#  '3/23/20',
#  '3/24/20',
#  '3/25/20',
#  '3/26/20',
#  '3/27/20',
#  '3/28/20',
#  '3/29/20',
#  '3/3/20',
#  '3/30/20',
#  '3/31/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '4/1/20',
#  '4/10/20',
#  '4/11/20',
#  '4/12/20',
#  '4/13/20',
#  '4/14/20',
#  '4/15/20',
#  '4/16/20',
#  '4/17/20',
#  '4/18/20',
#  '4/19/20',
#  '4/2/20',
#  '4/20/20',
#  '4/21/20',
#  '4/22/20',
#  '4/3/20',
#  '4/4/20',
#  '4/5/20',
#  '4/6/20',
#  '4/7/20',
#  '4/8/20',
#  '4/9/20',
#  'Country/Region',
#  'Lat',
#  'Long',
#  'Province/State'}

# %%
#list of common columns
common_cols = confirmed_col.intersection(deaths_col)
common_cols
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20',
#        '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20',
#        '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20',
#        '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20',
#        '4/15/20', '4/16/20', '4/17/20', '4/18/20', '4/19/20', '4/20/20',
#        '4/21/20', '4/22/20'],
#       dtype='object')

# %%
#Check number of entries in each column
confirmed_cases_df.count()
# Out:
# Province/State     82
# Country/Region    264
# Lat               264
# Long              264
# 1/22/20           264
#                  ...
# 4/18/20           264
# 4/19/20           264
# 4/20/20           264
# 4/21/20           264
# 4/22/20           264
# Length: 96, dtype: int64

# %%
deaths_df.count()
# Out:
# Province/State     82
# Country/Region    264
# Lat               264
# Long              264
# 1/22/20           264
#                  ...
# 4/18/20           264
# 4/19/20           264
# 4/20/20           264
# 4/21/20           264
# 4/22/20           264
# Length: 96, dtype: int64

# %%
recovered_cases_df.count()
# Out:
# Province/State     67
# Country/Region    250
# Lat               250
# Long              250
# 1/22/20           250
#                  ...
# 4/18/20           250
# 4/19/20           250
# 4/20/20           250
# 4/21/20           250
# 4/22/20           250
# Length: 96, dtype: int64

# %%
#Remove province category since it has limited and different entries in each file
confirmed_cases_df = confirmed_cases_df.drop(columns=["Province/State"])

# %%
deaths_df.columns.difference(confirmed_cases_df.columns)
# Out:
# Index(['Province/State'], dtype='object')

# %%
recovered_cases_df.columns.difference(confirmed_cases_df.columns)
# Out:
# Index(['Province/State'], dtype='object')

# %%
deaths_df = deaths_df.drop(columns=["Province/State"])
recovered_cases_df = recovered_cases_df.drop(columns=["Province/State"])

# %%
confirmed_cases_df["Country/Region"].value_counts()
# Out:
# China             33
# Canada            15
# United Kingdom    11
# France            11
# Australia          8
#                   ..
# Cote d'Ivoire      1
# Mongolia           1
# Norway             1
# Ghana              1
# Liberia            1
# Name: Country/Region, Length: 185, dtype: int64

# %%
deaths_df["Country/Region"].value_counts()
# Out:
# China             33
# Canada            15
# United Kingdom    11
# France            11
# Australia          8
#                   ..
# Cote d'Ivoire      1
# Mongolia           1
# Norway             1
# Ghana              1
# Liberia            1
# Name: Country/Region, Length: 185, dtype: int64

# %%
recovered_cases_df["Country/Region"].value_counts()
# Out:
# China             33
# France            11
# United Kingdom    11
# Australia          8
# Netherlands        5
#                   ..
# Cote d'Ivoire      1
# Mongolia           1
# Guinea-Bissau      1
# Ghana              1
# Liberia            1
# Name: Country/Region, Length: 185, dtype: int64

# %%
recovered_cases_df = recovered_cases_df.groupby(["Country/Region"])

recovered_cases_df.get_group("Canada")
# Out:
#    Country/Region      Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
#
\
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...      665      714
# Albania                   0        0        0        0  ...      467      475
# Algeria                   0        0        0        0  ...     1983     2070
# Andorra                   0        0        0        0  ...      646      659
# Angola                    0        0        0        0  ...       19       19
# ...                     ...      ...      ...      ...  ...      ...      ...
# West Bank and Gaza        0        0        0        0  ...      308      308
# Western Sahara            0        0        0        0  ...        6        6
# Yemen                     0        0        0        0  ...        1        1
# Zambia                    0        0        0        0  ...       45       45
# Zimbabwe                  0        0        0        0  ...       17       17
#
#                     4/15/20  4/16/20  4/17/20  4/18/20  4/19/20  4/20/20  \
# Country/Region
# Afghanistan             784      840      906      933      996     1026
# Albania                 494      518      539      548      562      584
# Algeria                2160     2268     2418     2534     2629     2718
# Andorra                 673      673      696      704      713      717
# Angola                   19       19       19       24       24       24
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza      374      374      402      418      437      449
# Western Sahara            6        6        6        6        6        6
# Yemen                     1        1        1        1        1        1
# Zambia                   48       48       52       57       61       65
# Zimbabwe                 23       23       24       25       25       25
#
#                     4/21/20  4/22/20
# Country/Region
# Afghanistan            1092     1176
# Albania                 609      634
# Algeria                2811     2910
# Andorra                 717      723
# Angola                   24       25
# ...                     ...      ...
# West Bank and Gaza      466      474
# Western Sahara            6        6
# Yemen                     1        1
# Zambia                   70       74
# Zimbabwe                 28       28
#
# [185 rows x 94 columns]

# %%
#Repeat the above for deaths_df
deaths_df = deaths_df.groupby(["Country/Region"])
deaths_sum_df = deaths_df.sum()
deaths_sum_df
# Out:
#                           Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan         33.000000  65.000000        0        0        0        0
# Albania             41.153300  20.168300        0        0        0        0
# Algeria             28.033900   1.659600        0        0        0        0
# Andorra             42.506300   1.521800        0        0        0        0
# Angola             -11.202700  17.873900        0        0        0        0
# ...                       ...        ...      ...      ...      ...      ...
# West Bank and Gaza  31.952200  35.233200        0        0        0        0
# Western Sahara      24.215500 -12.885800        0        0        0        0
# Yemen               15.552727  48.516388        0        0        0        0
# Zambia             -15.416700  28.283300        0        0        0        0
# Zimbabwe           -20.000000  30.000000        0        0        0        0
#
#                     1/26/20  1/27/20  1/28/20  1/29/20  ...  4/13/20  4/14/20  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...       21       23
# Albania                   0        0        0        0  ...       23       24
# Algeria                   0        0        0        0  ...      313      326
# Andorra                   0        0        0        0  ...       29       31
# Angola                    0        0        0        0  ...        2        2
# ...                     ...      ...      ...      ...  ...      ...      ...
# West Bank and Gaza        0        0        0        0  ...        2        2
# Western Sahara            0        0        0        0  ...        0        0
# Yemen                     0        0        0        0  ...        0        0
# Zambia                    0        0        0        0  ...        2        2
# Zimbabwe                  0        0        0        0  ...        3        3
#
#                     4/15/20  4/16/20  4/17/20  4/18/20  4/19/20  4/20/20  \
# Country/Region
# Afghanistan              25       30       30       30       33       36
# Albania                  25       26       26       26       26       26
# Algeria                 336      348      364      367      375      384
# Andorra                  33       33       35       35       36       37
# Angola                    2        2        2        2        2        2
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        2        2        2        2        3        3
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    2        2        2        2        3        3
# Zimbabwe                  3        3        3        3        3        3
#
#                     4/21/20  4/22/20
# Country/Region
# Afghanistan              36       40
# Albania                  26       27
# Algeria                 392      402
# Andorra                  37       37
# Angola                    2        2
# ...                     ...      ...
# West Bank and Gaza        4        4
# Western Sahara            0        0
# Yemen                     0        0
# Zambia                    3        3
# Zimbabwe                  3        4
#
# [185 rows x 94 columns]

# %%
#Repeat the above for recovered_cases_df
recovered_sum_cases_df = recovered_cases_df.sum()
recovered_sum_cases_df
# Out:
#                           Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan         33.000000  65.000000        0        0        0        0
# Albania             41.153300  20.168300        0        0        0        0
# Algeria             28.033900   1.659600        0        0        0        0
# Andorra             42.506300   1.521800        0        0        0        0
# Angola             -11.202700  17.873900        0        0        0        0
# ...                       ...        ...      ...      ...      ...      ...
# West Bank and Gaza  31.952200  35.233200        0        0        0        0
# Western Sahara      24.215500 -12.885800        0        0        0        0
# Yemen               15.552727  48.516388        0        0        0        0
# Zambia             -15.416700  28.283300        0        0        0        0
# Zimbabwe           -20.000000  30.000000        0        0        0        0
#
#                     1/26/20  1/27/20  1/28/20  1/29/20  ...  4/13/20  4/14/20  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...       32       40
# Albania                   0        0        0        0  ...      232      248
# Algeria                   0        0        0        0  ...      601      691
# Andorra                   0        0        0        0  ...      128      128
# Angola                    0        0        0        0  ...        4        5
# ...                     ...      ...      ...      ...  ...      ...      ...
# West Bank and Gaza        0        0        0        0  ...       58       62
# Western Sahara            0        0        0        0  ...        0        0
# Yemen                     0        0        0        0  ...        0        0
# Zambia                    0        0        0        0  ...       30       30
# Zimbabwe                  0        0        0        0  ...        0        0
#
#                     4/15/20  4/16/20  4/17/20  4/18/20  4/19/20  4/20/20  \
# Country/Region
# Afghanistan              43       54       99      112      131      135
# Albania                 251      277      283      302      314      327
# Algeria                 708      783      846      894     1047     1099
# Andorra                 169      169      191      205      235      248
# Angola                    5        5        5        6        6        6
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza       63       63       69       69       71       71
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                   30       30       30       33       33       35
# Zimbabwe                  1        1        2        2        2        2
#
#                     4/21/20  4/22/20
# Country/Region
# Afghanistan             150      166
# Albania                 345      356
# Algeria                1152     1204
# Andorra                 282      309
# Angola                    6        6
# ...                     ...      ...
# West Bank and Gaza       71       71
# Western Sahara            0        0
# Yemen                     0        0
# Zambia                   35       35
# Zimbabwe                  2        2
#
# [185 rows x 94 columns]

# %%
confirmed_cases_sum_df = confirmed_cases_sum_df.sort_values(by=["Country/Region"])
deaths_sum_df = deaths_sum_df.sort_values(by=["Country/Region"])
recovered_sum_cases_df = recovered_sum_cases_df.sort_values(by=["Country/Region"])

# %%
confirmed_cases_sum_df = confirmed_cases_sum_df.reset_index()
confirmed_cases_sum_df
# Out:
#          Country/Region        Lat       Long  1/22/20  1/23/20  1/24/20  \
# 0           Afghanistan  33.000000  65.000000        0        0        0
# 1               Albania  41.153300  20.168300        0        0        0
# 2               Algeria  28.033900   1.659600        0        0        0
# 3               Andorra  42.506300   1.521800        0        0        0
# 4                Angola -11.202700  17.873900        0        0        0
# ..                  ...        ...        ...      ...      ...      ...
# 180  West Bank and Gaza  31.952200  35.233200        0        0        0
# 181      Western Sahara  24.215500 -12.885800        0        0        0
# 182               Yemen  15.552727  48.516388        0        0        0
# 183              Zambia -15.416700  28.283300        0        0        0
# 184            Zimbabwe -20.000000  30.000000        0        0        0
#
#      1/25/20  1/26/20  1/27/20  1/28/20  ...  4/13/20  4/14/20  4/15/20  \
# 0          0        0        0        0  ...      665      714      784
# 1          0        0        0        0  ...      467      475      494
# 2          0        0        0        0  ...     1983     2070     2160
# 3          0        0        0        0  ...      646      659      673
# 4          0        0        0        0  ...       19       19       19
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 180        0        0        0        0  ...      308      308      374
# 181        0        0        0        0  ...        6        6        6
# 182        0        0        0        0  ...        1        1        1
# 183        0        0        0        0  ...       45       45       48
# 184        0        0        0        0  ...       17       17       23
#
#      4/16/20  4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0        840      906      933      996     1026     1092     1176
# 1        518      539      548      562      584      609      634
# 2       2268     2418     2534     2629     2718     2811     2910
# 3        673      696      704      713      717      717      723
# 4         19       19       24       24       24       24       25
# ..       ...      ...      ...      ...      ...      ...      ...
# 180      374      402      418      437      449      466      474
# 181        6        6        6        6        6        6        6
# 182        1        1        1        1        1        1        1
# 183       48       52       57       61       65       70       74
# 184       23       24       25       25       25       28       28
#
# [185 rows x 95 columns]

# %%
recovered_sum_cases_df = recovered_sum_cases_df.reset_index()
recovered_sum_cases_df
# Out:
#          Country/Region        Lat       Long  1/22/20  1/23/20  1/24/20  \
# 0           Afghanistan  33.000000  65.000000        0        0        0
# 1               Albania  41.153300  20.168300        0        0        0
# 2               Algeria  28.033900   1.659600        0        0        0
# 3               Andorra  42.506300   1.521800        0        0        0
# 4                Angola -11.202700  17.873900        0        0        0
# ..                  ...        ...        ...      ...      ...      ...
# 180  West Bank and Gaza  31.952200  35.233200        0        0        0
# 181      Western Sahara  24.215500 -12.885800        0        0        0
# 182               Yemen  15.552727  48.516388        0        0        0
# 183              Zambia -15.416700  28.283300        0        0        0
# 184            Zimbabwe -20.000000  30.000000        0        0        0
#
#      1/25/20  1/26/20  1/27/20  1/28/20  ...  4/13/20  4/14/20  4/15/20  \
# 0          0        0        0        0  ...       32       40       43
# 1          0        0        0        0  ...      232      248      251
# 2          0        0        0        0  ...      601      691      708
# 3          0        0        0        0  ...      128      128      169
# 4          0        0        0        0  ...        4        5        5
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 180        0        0        0        0  ...       58       62       63
# 181        0        0        0        0  ...        0        0        0
# 182        0        0        0        0  ...        0        0        0
# 183        0        0        0        0  ...       30       30       30
# 184        0        0        0        0  ...        0        0        1
#
#      4/16/20  4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# 0         54       99      112      131      135      150      166
# 1        277      283      302      314      327      345      356
# 2        783      846      894     1047     1099     1152     1204
# 3        169      191      205      235      248      282      309
# 4          5        5        6        6        6        6        6
# ..       ...      ...      ...      ...      ...      ...      ...
# 180       63       69       69       71       71       71       71
# 181        0        0        0        0        0        0        0
# 182        0        0        0        0        0        0        0
# 183       30       30       33       33       35       35       35
# 184        1        2        2        2        2        2        2
#
# [185 rows x 95 columns]

# %%
deaths_sum_df = deaths_sum_df.reset_index()
deaths_sum_df.index.name = 'ID'
deaths_sum_df
# Out:
#          Country/Region        Lat       Long  1/22/20  1/23/20  1/24/20  \
# ID
# 0           Afghanistan  33.000000  65.000000        0        0        0
/16/20  4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# ID
# 0         54       99      112      131      135      150      166
# 1        277      283      302      314      327      345      356
# 2        783      846      894     1047     1099     1152     1204
# 3        169      191      205      235      248      282      309
# 4          5        5        6        6        6        6        6
# ..       ...      ...      ...      ...      ...      ...      ...
# 180       63       69       69       71       71       71       71
# 181        0        0        0        0        0        0        0
# 182        0        0        0        0        0        0        0
# 183       30       30       33       33       35       35       35
# 184        1        2        2        2        2        2        2
#
# [185 rows x 95 columns]

# %%
confirmed_cases_sum_df.index.name = 'ID'
confirmed_cases_sum_df
# Out:
#          Country/Region        Lat       Long  1/22/20  1/23/20  1/24/20  \
# ID
# 0           Afghanistan  33.000000  65.000000        0        0        0
# 1               Albania  41.153300  20.168300        0        0        0
# 2               Algeria  28.033900   1.659600        0        0        0
# 3               Andorra  42.506300   1.521800        0        0        0
# 4                Angola -11.202700  17.873900        0        0        0
# ..                  ...        ...        ...      ...      ...      ...
# 180  West Bank and Gaza  31.952200  35.233200        0        0        0
# 181      Western Sahara  24.215500 -12.885800        0        0        0
# 182               Yemen  15.552727  48.516388        0        0        0
# 183              Zambia -15.416700  28.283300        0        0        0
# 184            Zimbabwe -20.000000  30.000000        0        0        0
#
#      1/25/20  1/26/20  1/27/20  1/28/20  ...  4/13/20  4/14/20  4/15/20  \
# ID                                       ...
# 0          0        0        0        0  ...      665      714      784
# 1          0        0        0        0  ...      467      475      494
# 2          0        0        0        0  ...     1983     2070     2160
# 3          0        0        0        0  ...      646      659      673
# 4          0        0        0        0  ...       19       19       19
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 180        0        0        0        0  ...      308      308      374
# 181        0        0        0        0  ...        6        6        6
# 182        0        0        0        0  ...        1        1        1
# 183        0        0        0        0  ...       45       45       48
# 184        0        0        0        0  ...       17       17       23
#
#      4/16/20  4/17/20  4/18/20  4/19/20  4/20/20  4/21/20  4/22/20
# ID
# 0        840      906      933      996     1026     1092     1176
# 1        518      539      548      562      584      609      634
# 2       2268     2418     2534     2629     2718     2811     2910
# 3        673      696      704      713      717      717      723
# 4         19       19       24       24       24       24       25
# ..       ...      ...      ...      ...      ...      ...      ...
# 180      374      402      418      437      449      466      474
# 181        6        6        6        6        6        6        6
# 182        1        1        1        1        1        1        1
# 183       48       52       57       61       65       70       74
# 184       23       24       25       25       25       28       28
#
# [185 rows x 95 columns]

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:lujane92@localhost:5432/ETL_Project_Corona"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['confirmed_cases']

# %% [markdown]
# ### Load DataFrames into database

# %%
confirmed_cases_sum_df.to_sql(name='confirmed_cases', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "ID" of relation "confirmed_cases" does not exist
# LINE 1: INSERT INTO confirmed_cases ("ID", "Country/Region", "Lat", ...
#                                      ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-98-ad540a61dca3> in <module>
# ----> 1 confirmed_cases_sum_df.to_sql(name='confirmed_cases', con=engine, if_exists='append', index=True)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2660             chunksize=chunksize,
#    2661             dtype=dtype,
# -> 2662             method=method,
#    2663         )
#    2664
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1224                 if not evt_handled:
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#    1228             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "ID" of relation "confirmed_cases" does not exist
# LINE 1: INSERT INTO confirmed_cases ("ID", "Country/Region", "Lat", ...
#                                      ^
#
# [SQL: INSERT INTO confirmed_cases ("ID", "Country/Region", "Lat", "Long", "1/22/20", "1/23/20", "1/24/20", "1/25/20", "1/26/20", "1/27/20", "1/28/20", "1/29/20", "1/30/20", "1/31/20", "2/1/20", "2/2/20", "2/3/20", "2/4/20", "2/5/20", "2/6/20", "2/7/20", "2/8/20", "2/9/20", "2/10/20", "2/11/20", "2/12/20", "2/13/20", "2/14/20", "2/15/20", "2/16/20", "2/17/20", "2/18/20", "2/19/20", "2/20/20", "2/21/20", "2/22/20", "2/23/20", "2/24/20", "2/25/20", "2/26/20", "2/27/20", "2/28/20", "2/29/20", "3/1/20", "3/2/20", "3/3/20", "3/4/20", "3/5/20", "3/6/20", "3/7/20", "3/8/20", "3/9/20", "3/10/20", "3/11/20", "3/12/20", "3/13/20", "3/14/20", "3/15/20", "3/16/20", "3/17/20", "3/18/20", "3/19/20", "3/20/20", "3/21/20", "3/22/20", "3/23/20", "3/24/20", "3/25/20", "3/26/20", "3/27/20", "3/28/20", "3/29/20", "3/30/20", "3/31/20", "4/1/20", "4/2/20", "4/3/20", "4/4/20", "4/5/20", "4/6/20", "4/7/20", "4/8/20", "4/9/20", "4/10/20", "4/11/20", "4/12/20", "4/13/20", "4/14/20", "4/15/20", "4/16/20", "4/17/20", "4/18/20", "4/19/20", "4/20/20", "4/21/20", "4/22/20") VALUES (%(ID)s, %(Country/Region)s, %(Lat)s, %(Long)s, %(1/22/20)s, %(1/23/20)s, %(1/24/20)s, %(1/25/20)s, %(1/26/20)s, %(1/27/20)s, %(1/28/20)s, %(1/29/20)s, %(1/30/20)s, %(1/31/20)s, %(2/1/20)s, %(2/2/20)s, %(2/3/20)s, %(2/4/20)s, %(2/5/20)s, %(2/6/20)s, %(2/7/20)s, %(2/8/20)s, %(2/9/20)s, %(2/10/20)s, %(2/11/20)s, %(2/12/20)s, %(2/13/20)s, %(2/14/20)s, %(2/15/20)s, %(2/16/20)s, %(2/17/20)s, %(2/18/20)s, %(2/19/20)s, %(2/20/20)s, %(2/21/20)s, %(2/22/20)s, %(2/23/20)s, %(2/24/20)s, %(2/25/20)s, %(2/26/20)s, %(2/27/20)s, %(2/28/20)s, %(2/29/20)s, %(3/1/20)s, %(3/2/20)s, %(3/3/20)s, %(3/4/20)s, %(3/5/20)s, %(3/6/20)s, %(3/7/20)s, %(3/8/20)s, %(3/9/20)s, %(3/10/20)s, %(3/11/20)s, %(3/12/20)s, %(3/13/20)s, %(3/14/20)s, %(3/15/20)s, %(3/16/20)s, %(3/17/20)s, %(3/18/20)s, %(3/19/20)s, %(3/20/20)s, %(3/21/20)s, %(3/22/20)s, %(3/23/20)s, %(3/24/20)s, %(3/25/